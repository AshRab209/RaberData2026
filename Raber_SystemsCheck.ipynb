# %% [markdown]
# # This is a Header!

# %% [markdown]
# ## This is a sub header. In this class I hope to learn how to code better and in more practical ways. Also I want to strive to get an A

# %% [markdown]
# ![silly emoji](https://i.redd.it/i-love-these-silly-emojis-v0-pm2zqgvosi9h1.jpg?width=610&format=pjpg&auto=webp&s=84a9c9cc3ad6927c339a58e22b403b30204a4c66)

# %% [markdown]
# 1. This should be an ordered list. I googled how to do it
# 2. indeed it is i hit enter and theres 2
# 3. aha
# 4. okay thats enough have a good day!

# %% [markdown]
# **This should be bold i belive** it is. *this is italic then* awesome.

# %%
print("i want extra credit heres my proof i can do it")
# Out:
# i want extra credit heres my proof i can do it

# %%
x=12

# %%
for i in range(7):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6

# %%
def addnumbers(a,b,c):
    result=a+b+c
    return result
addnumbers(10,76,38)
# Out:
# 124

# %%
print("have a great day. i know some code")
# Out:
# have a great day. i know some code
